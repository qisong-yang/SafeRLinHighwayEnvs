# %%
# %run  ./plot.py ../fix_speed_01_plr5.0_limit0.1    -y 'AverageEpRet' 'AverageEpCost' 'EpLen' 'CostRate' 'LossV' 'LossPi' 'Penalty' -s 1
# Out:
# Plotting from...
# ...
#
# ../fix_speed_01_plr5.0_limit0.1
#
# ...
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# %run  ./plot.py ../fix_speed_01_plr0.5_    -y 'AverageEpRet' 'AverageEpCost' 'EpLen' 'CostRate' 'LossV' 'LossPi' 'Penalty' -s 1
# Out:
# Plotting from...
# ...
#
# ../fix_speed_01_plr0.5_
#
# ...
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# %run  ./plot.py ../speed_0_30_penalty_init20_   -y 'AverageEpRet' 'AverageEpCost' 'EpLen' 'CostRate' 'LossV' 'LossPi' 'Penalty' -s 1
# Out:
# Plotting from...
# ...
#
# ../speed_0_30_penalty_init20_
#
# ...
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# %run  ./plot.py   ../fix_speed_01_plr0.5_ ../speed_0_30_penalty_init100_ --count -y 'AverageEpRet' 'AverageEpCost' 'EpLen' 'CostRate' 'LossV' 'LossPi' 'Penalty' -s 1
# Out:
# Plotting from...
# ...
#
# ../fix_speed_01_plr0.5_
# ../speed_0_30_penalty_init100_
#
# ...
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# %run  ./plot.py  ../speed_0_30_penalty_init75_  ../speed_0_30_penalty_init100_ ../speed_0_30_penalty_init500_ --count --legend '50' '100' '500' -y 'AverageEpRet' 'AverageEpCost' 'EpLen' 'CostRate' 'LossV' 'LossPi' 'Penalty' -s 1
# Out:
# Plotting from...
# ...
#
# ../speed_0_30_penalty_init75_
# ../speed_0_30_penalty_init100_
# ../speed_0_30_penalty_init500_
#
# ...
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# %run  ./plot.py   ../speed_0_30_penalty_init999 -y 'AverageEpRet' 'AverageEpCost' 'EpLen' 'CostRate' 'LossV' 'LossPi' 'Penalty' -s 1
# Out:
# Plotting from...
# ...
#
# ../speed_0_30_penalty_init999
#
# ...
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/kamran/.virtualenvs/hels_py3/lib/python3.6/site-packages/seaborn/timeseries.py:357: UserWarning: Attempting to set identical left == right == 5000.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(x.min(), x.max())
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/wiss/kamran/programming/constrained_RL/SafeRLinHighwayEnvs/scripts/plot.py in <module>
#     340
#     341 if __name__ == "__main__":
# --> 342     main()
#
# /home/wiss/kamran/programming/constrained_RL/SafeRLinHighwayEnvs/scripts/plot.py in main()
# ...
